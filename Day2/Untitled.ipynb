# %%
import pandas as pd

# %%
train_data = pd.read_csv(r'../data/train_data_modified.csv')

# %%
train_data.tail()
# Out:
#      CategoryCode  ItemCode Week  id  WeeklySales
# 3767   category_1   1044619   w4  20           45
# 3768   category_4     23200   w4  20           22
# 3769   category_1   1084498   w4  20            7
# 3770   category_4    872260   w4  20           12
# 3771   category_4   1024810   w4  20           21

# %%
train_data.sort_values(by = ['ItemCode', 'id']).shape
# Out:
# (3772, 5)

# %%
train_data_reg = pd.read_csv(r'../data/train_data_regression.csv').drop(0, axis = 0)

# %%
train_data_reg
# Out:
#                        1           2           3           4           5    \
# ItemCode            3418.0      3427.0      7666.0      9925.0     16936.0
# CategoryCode    category_1  category_1  category_3  category_2  category_3
# WeeklySales           29.0        11.0        84.0         1.0         9.0
# WeeklySales.1         42.0        40.0       119.0         9.0        25.0
# WeeklySales.2         41.0        20.0       196.0        11.0        40.0
# WeeklySales.3         41.0        48.0       185.0        13.0        31.0
# WeeklySales.4         44.0        54.0        94.0         5.0        21.0
# WeeklySales.5         46.0        28.0        15.0        11.0        43.0
# WeeklySales.6         43.0        36.0        10.0        11.0         7.0
# WeeklySales.7         49.0        52.0        30.0        13.0        34.0
# WeeklySales.8         54.0        42.0        79.0        12.0       151.0
# ...

# %%
train_data_reg['ItemCode']
# Out:
# 1         3418.0
# 2         3427.0
# 3         7666.0
# 4         9925.0
# 5        16936.0
#          ...
# 190    1101769.0
# 191    1103056.0
# 192    1105009.0
# 193    1105018.0
# 194    1105027.0
# Name: ItemCode, Length: 194, dtype: float64

# %%
for item_code in train_data_reg['ItemCode']:
